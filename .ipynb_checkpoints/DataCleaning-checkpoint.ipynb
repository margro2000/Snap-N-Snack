# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
filepath = "../COVID Healthy diet dataset/Fat_Supply_Quantity_Data.csv"

df = pd.read_csv(filepath)

# %%
df.head()
# Out:
#                Country  Alcoholic Beverages  Animal Products  Animal fats  \
# 0          Afghanistan                  0.0          21.6397       6.2224
# 1              Albania                  0.0          32.0002       3.4172
# 2              Algeria                  0.0          14.4175       0.8972
# 3               Angola                  0.0          15.3041       1.3130
# 4  Antigua and Barbuda                  0.0          27.7033       4.6686
#
#    Aquatic Products, Other  Cereals - Excluding Beer    Eggs  Fish, Seafood  \
# 0                      0.0                    8.0353  0.6859         0.0327
# 1                      0.0                    2.6734  1.6448         0.1445
# 2                      0.0                    4.2035  1.2171         0.2008
# 3                      0.0                    6.5545  0.1539         1.4155
# 4                      0.0                    3.2153  0.3872         1.5263
#
#    Fruits - Excluding Wine     Meat  ...  Vegetable Oils  Vegetables  Obesity  \
# 0                   0.4246   6.1244  ...         17.0831      0.3593      4.5
# 1                   0.6418   8.7428  ...          9.2443      0.6503     22.3
# 2                   0.5772   3.8961  ...         27.3606      0.5145     26.6
# 3                   0.3488  11.0268  ...         22.4638      0.1231      6.8
# 4                   1.2177  14.3202  ...         14.4436      0.2469     19.1
#
#    Undernourished  Population  Confirmed    Deaths  Recovered    Active  \
# 0            29.8  38928000.0   0.103491  0.003846   0.086724  0.012921
# 1             6.2   2838000.0   0.611346  0.015997   0.358245  0.237104
# 2             3.9  44357000.0   0.123128  0.004205   0.086153  0.032770
# 3              25  32522000.0   0.024073  0.000763   0.009320  0.013991
# 4             NaN     98000.0   0.121429  0.003061   0.103061  0.015306
#
#    Unit (all except Population)
# 0                             %
# 1                             %
# 2                             %
# 3                             %
# 4                             %
#
# [5 rows x 32 columns]

# %% [markdown]
# Setting the 'Country' column as the index.

# %%
df.set_index("Country", inplace=True)

# %% [markdown]
# Removing unnecessary column (only contains information about the unit of rest of the columns)

# %%
to_drop = ["Unit (all except Population)", "Deaths", "Active", "Recovered"]
df.drop(columns=to_drop, inplace=True, axis=1)

# %% [markdown]
# Normalizing popuation feature to millions (to remove bias due to very high values)

# %%
df['Population'] = df['Population'] / 1000000

# %% [markdown]
# Converting 'string' type columns to numeric datatype.
#
# Dataset contains any percentage below 2.5% denotes as '<2.5'. Converting those values to 2.0 just as a crude way to handle the issue.

# %%
df['Undernourished'] = df['Undernourished'].replace('<2.5', 2.0)

# %%
df['Undernourished'] = pd.to_numeric(df['Undernourished'])

# %% [markdown]
# Ensuring all the columns are numeric

# %%
df.dtypes.value_counts()
# Out:
# float64    27
# dtype: int64

# %% [markdown]
# Vizualizing the data with a heatmap to see where the missing values lie, we ca see that -
#
# Other than features such as Obesity and Undernourished %, there are columns that will serve as label data which is missing ( COVID Confirmed, Deatth, Recovered, Active cases). These rows would be useless, since the feature data will give no insight on the COVID stats).
#
# We will drop these rows.

# %%
import seaborn as sns
cols = df.columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
df = df[df['Confirmed'].notna()]

# %% [markdown]
# Now, for the remaining missing values, we will use KNN algorithm to impute the missing values.
#
# We use sklearn to achieve this.

# %%
imputer = KNNImputer(missing_values=np.nan, n_neighbors=5)
df[:] = imputer.fit_transform(df)

# %% [markdown]
# Checking whether algorithm can successfully and that all the missing values are removed.

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Now that we have cleaned the data, let's visualize the dataset to see if there are some outliers.

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see that there is an outlier in the population column, so let's plot this feature separately.

# %%
df.boxplot(column='Population')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Defining the features and labels.

# %%
# Separating out the features
features = ['Alcoholic Beverages',
 'Animal Products',
 'Animal fats',
 'Aquatic Products, Other',
 'Cereals - Excluding Beer',
 'Eggs',
 'Fish, Seafood',
 'Fruits - Excluding Wine',
 'Meat',
 'Miscellaneous',
 'Milk - Excluding Butter',
 'Offals',
 'Oilcrops',
 'Pulses',
 'Spices',
 'Starchy Roots',
 'Stimulants',
 'Sugar Crops',
 'Sugar & Sweeteners',
 'Treenuts',
 'Vegetal Products',
 'Vegetable Oils',
 'Vegetables',
 'Obesity',
 'Undernourished',
 'Population']

l1 = ['Confirmed']

# Separating the features
x = df.loc[:, features]

# Separating the target
y1 = df.loc[:,l1]

# %%
# Standardizing the features
x = StandardScaler().fit_transform(x)
x = pd.DataFrame(x, index=df.index, columns=features)

# %%
from scipy.spatial.distance import cdist

Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
score = [kmeans[i].fit(x).score(x) for i in range(len(kmeans))]
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
corr = x.corr()

# %%
plt.figure(figsize = (10,7))
sns.heatmap(corr, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
# Separating out the features
features1 = [
 'Aquatic Products, Other',
 'Eggs',
 'Meat',
 'Offals',
 'Pulses',
 'Spices',
 'Sugar Crops',
 'Sugar & Sweeteners',
 'Treenuts',
 'Vegetables',
 'Obesity',
 'Undernourished',
 'Population']

l21 = ['Confirmed']

# Separating the features
x1 = df.loc[:, features1]

# Separating the target
y21 = df.loc[:,l21]

# %%
corr = x1.corr()

# %%
plt.figure(figsize = (10,7))
sns.heatmap(corr, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
from scipy.spatial.distance import cdist

Nc = range(1, 20)
kmeans = [KMeans(n_clusters=i) for i in Nc]
score = [kmeans[i].fit(x).score(x) for i in range(len(kmeans))]
plt.plot(Nc,score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf
# Out:
#      principal component 1  principal component 2
# 0                 0.777213               0.390163
# 1                -3.021458               0.895816
# 2                 0.492205              -2.006421
# 3                 2.792799               0.299022
# 4                -1.575865               1.001851
# ..                     ...                    ...
# 157               1.020633              -1.823291
# 158              -1.468554               3.945433
# 159               2.962307              -0.437323
# 160               4.458615               1.039332
# 161               3.410341              -1.603976
#
# [162 rows x 2 columns]
