# %%
import pandas as pd

# %%
# !ls ../data/nhne/
# Out:
# demographic.csv   examination.csv   medications.csv
# diet.csv          labs.csv          questionnaire.csv

# %%
df = pd.read_csv("../data/nhne/diet.csv")
df.head()
# Out:
#     SEQN         WTDRD1         WTDR2D  DR1DRSTZ  DR1EXMER  DRABF  DRDINT  \
# 0  73557   16888.327864   12930.890649         1      49.0    2.0     2.0
# 1  73558   17932.143865   12684.148869         1      59.0    2.0     2.0
# 2  73559   59641.812930   39394.236709         1      49.0    2.0     2.0
# 3  73560  142203.069917  125966.366442         1      54.0    2.0     2.0
# 4  73561   59052.357033   39004.892993         1      63.0    2.0     2.0
#
#    DR1DBIH  DR1DAY  DR1LANG  ...  DRD370QQ  DRD370R  DRD370RQ  DRD370S  \
# 0      6.0     2.0      1.0  ...       NaN      NaN       NaN      NaN
# 1      4.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
# 2     18.0     6.0      1.0  ...       NaN      NaN       NaN      NaN
# 3     21.0     3.0      1.0  ...       NaN      NaN       NaN      NaN
# 4     18.0     1.0      1.0  ...       NaN      2.0       NaN      2.0
#
#    DRD370SQ  DRD370T  DRD370TQ  DRD370U  DRD370UQ  DRD370V
# ...

# %%
# intake of nutrients for patient (SEQN) on the first day of the questionare.
cols = [
 'SEQN',
 'DR1TKCAL',
 'DR1TPROT',
 'DR1TCARB',
 'DR1TSUGR',
 'DR1TFIBE',
 'DR1TTFAT',
 'DR1TSFAT',
 'DR1TMFAT',
 'DR1TPFAT',
 'DR1TCHOL',
 'DR1TATOC',
 'DR1TATOA',
 'DR1TRET',
 'DR1TVARA',
 'DR1TACAR',
 'DR1TBCAR',
 'DR1TCRYP',
 'DR1TLYCO',
 'DR1TLZ',
 'DR1TVB1',
 'DR1TVB2',
 'DR1TNIAC',
 'DR1TVB6',
 'DR1TFOLA',
 'DR1TFA',
 'DR1TFF',
 'DR1TFDFE',
 'DR1TCHL',
 'DR1TVB12',
 'DR1TB12A',
 'DR1TVC',
 'DR1TVD',
 'DR1TVK',
 'DR1TCALC',
 'DR1TPHOS',
 'DR1TMAGN',
 'DR1TIRON',
 'DR1TZINC',
 'DR1TCOPP',
 'DR1TSODI',
 'DR1TPOTA',
 'DR1TSELE',
 'DR1TCAFF',
 'DR1TTHEO',
 'DR1TALCO',
 'DR1TMOIS',
]
df[cols].head()
# Out:
#     SEQN  DR1TKCAL  DR1TPROT  DR1TCARB  DR1TSUGR  DR1TFIBE  DR1TTFAT  \
# 0  73557    1574.0     43.63    239.59    176.47      10.8     52.81
# 1  73558    5062.0    338.13    423.78     44.99      16.7    124.29
# 2  73559    1743.0     64.61    224.39    102.90       9.9     65.97
# 3  73560    1490.0     77.75    162.92     80.58      10.6     58.27
# 4  73561    1421.0     55.24    178.20     87.78      12.3     55.36
#
#    DR1TSFAT  DR1TMFAT  DR1TPFAT  ...  DR1TIRON  DR1TZINC  DR1TCOPP  DR1TSODI  \
# 0    17.819    18.493     8.829  ...      8.41      8.85     1.072    1323.0
# 1    53.408    35.481    20.505  ...     26.88     30.36     4.130    9726.0
# 2    25.263    20.902    12.953  ...     17.57      8.98     0.949    2943.0
# 3    23.511    16.986     9.617  ...     14.19     13.84     0.542    2745.0
# 4     4.479    26.216     1.263  ...     17.72     17.73     1.984     797.0
#
#    DR1TPOTA  DR1TSELE  DR1TCAFF  DR1TTHEO  DR1TALCO  DR1TMOIS
# ...

# %%
#list(df.columns)

# %%
rel_df = df[cols].copy()

# %%
rel_df
# Out:
#        SEQN  DR1TKCAL  DR1TPROT  DR1TCARB  DR1TSUGR  DR1TFIBE  DR1TTFAT  \
# 0     73557    1574.0     43.63    239.59    176.47      10.8     52.81
# 1     73558    5062.0    338.13    423.78     44.99      16.7    124.29
# 2     73559    1743.0     64.61    224.39    102.90       9.9     65.97
# 3     73560    1490.0     77.75    162.92     80.58      10.6     58.27
# 4     73561    1421.0     55.24    178.20     87.78      12.3     55.36
# ...     ...       ...       ...       ...       ...       ...       ...
# 9808  83727    4687.0    223.32    494.54    160.63      30.4    193.51
# 9809  83728    1253.0     47.55    149.20     50.73       9.3     52.39
# 9810  83729    2475.0     89.37    290.37    126.54      25.7    110.30
# 9811  83730       NaN       NaN       NaN       NaN       NaN       NaN
# 9812  83731    2877.0     96.06    461.53    221.21      36.3     78.63
#
#       DR1TSFAT  DR1TMFAT  DR1TPFAT  ...  DR1TIRON  DR1TZINC  DR1TCOPP  \
# ...

# %%
rel_df = rel_df.dropna()

# %%
import matplotlib.pyplot as plt
def plot_corr(df):
    f = plt.figure(figsize=(19, 15))
    plt.matshow(df.corr(), fignum=f.number)
    plt.xticks(range(df.shape[1]), df.columns, fontsize=14, rotation=45)
    plt.yticks(range(df.shape[1]), df.columns, fontsize=14)
    cb = plt.colorbar()
    cb.ax.tick_params(labelsize=14)
    plt.title('Correlation Matrix', fontsize=16);

    # plt.matshow(rel_df.corr())
    plt.show()
plot_corr(rel_df.drop(columns=["SEQN"]))

# %% [markdown]
# Examination Data

# %%
df = pd.read_csv("../data/nhne/examination.csv")
df.head()
# Out:
#     SEQN  PEASCST1  PEASCTM1  PEASCCT1  BPXCHR  BPAARM  BPACSZ  BPXPLS  \
# 0  73557         1     620.0       NaN     NaN     1.0     4.0    86.0
# 1  73558         1     766.0       NaN     NaN     1.0     4.0    74.0
# 2  73559         1     665.0       NaN     NaN     1.0     4.0    68.0
# 3  73560         1     803.0       NaN     NaN     1.0     2.0    64.0
# 4  73561         1     949.0       NaN     NaN     1.0     3.0    92.0
#
#    BPXPULS  BPXPTY  ...  CSXLEAOD  CSXSOAOD  CSXGRAOD  CSXONOD  CSXNGSOD  \
# 0      1.0     1.0  ...       2.0       1.0       1.0      1.0       4.0
# 1      1.0     1.0  ...       3.0       1.0       2.0      3.0       4.0
# 2      1.0     1.0  ...       2.0       1.0       2.0      3.0       4.0
# 3      1.0     1.0  ...       NaN       NaN       NaN      NaN       NaN
# 4      1.0     1.0  ...       3.0       1.0       4.0      3.0       4.0
#
#    CSXSLTRT  CSXSLTRG  CSXNART  CSXNARG  CSAEFFRT
# ...

# %%
list(df.columns)
# Out:
# ['SEQN',
#  'PEASCST1',
#  'PEASCTM1',
#  'PEASCCT1',
#  'BPXCHR',
#  'BPAARM',
#  'BPACSZ',
#  'BPXPLS',
#  'BPXPULS',
#  'BPXPTY',
#  'BPXML1',
#  'BPXSY1',
#  'BPXDI1',
#  'BPAEN1',
#  'BPXSY2',
#  'BPXDI2',
#  'BPAEN2',
#  'BPXSY3',
#  'BPXDI3',
#  'BPAEN3',
#  'BPXSY4',
#  'BPXDI4',
#  'BPAEN4',
#  'BMDSTATS',
#  'BMXWT',
#  'BMIWT',
#  'BMXRECUM',
#  'BMIRECUM',
#  'BMXHEAD',
#  'BMIHEAD',
#  'BMXHT',
#  'BMIHT',
#  'BMXBMI',
#  'BMDBMIC',
#  'BMXLEG',
#  'BMILEG',
#  'BMXARML',
#  'BMIARML',
#  'BMXARMC',
#  'BMIARMC',
#  'BMXWAIST',
#  'BMIWAIST',
#  'BMXSAD1',
#  'BMXSAD2',
#  'BMXSAD3',
#  'BMXSAD4',
#  'BMDAVSAD',
#  'BMDSADCM',
#  'MGDEXSTS',
#  'MGD050',
#  'MGD060',
#  'MGQ070',
#  'MGQ080',
#  'MGQ090',
#  'MGQ100',
#  'MGQ110',
#  'MGQ120',
#  'MGD130',
#  'MGQ90DG',
#  'MGDSEAT',
#  'MGAPHAND',
#  'MGATHAND',
#  'MGXH1T1',
#  'MGXH1T1E',
#  'MGXH2T1',
#  'MGXH2T1E',
#  'MGXH1T2',
#  'MGXH1T2E',
#  'MGXH2T2',
#  'MGXH2T2E',
#  'MGXH1T3',
#  'MGXH1T3E',
#  'MGXH2T3',
# ...

# %%
my_cols = ['SEQN', 'BPXSY1', 'BPXSY2', 'BPXSY3', 'BMXBMI']
# my_cols = ['SEQN', 'BPXSY1', 'BMXBMI']
df= df[my_cols]
df
# Out:
#        SEQN  BPXSY1  BPXSY2  BPXSY3  BMXBMI
# 0     73557   122.0   114.0   102.0    26.7
# 1     73558   156.0   160.0   156.0    28.6
# 2     73559   140.0   140.0   146.0    28.9
# 3     73560   108.0   102.0   104.0    17.1
# 4     73561   136.0   134.0   142.0    19.7
# ...     ...     ...     ...     ...     ...
# 9808  83727   110.0   116.0   112.0    24.5
# 9809  83728     NaN     NaN     NaN    15.9
# 9810  83729   136.0   130.0   138.0    34.0
# 9811  83730     NaN     NaN     NaN    16.1
# 9812  83731    94.0    94.0    90.0    19.3
#
# [9813 rows x 5 columns]

# %%
df.dropna()
# Out:
#        SEQN  BPXSY1  BPXSY2  BPXSY3  BMXBMI
# 0     73557   122.0   114.0   102.0    26.7
# 1     73558   156.0   160.0   156.0    28.6
# 2     73559   140.0   140.0   146.0    28.9
# 3     73560   108.0   102.0   104.0    17.1
# 4     73561   136.0   134.0   142.0    19.7
# ...     ...     ...     ...     ...     ...
# 9802  83721   108.0   112.0   108.0    25.6
# 9805  83724   164.0   168.0   168.0    24.9
# 9808  83727   110.0   116.0   112.0    24.5
# 9810  83729   136.0   130.0   138.0    34.0
# 9812  83731    94.0    94.0    90.0    19.3
#
# [6909 rows x 5 columns]

# %%
plot_corr(df.drop(columns=["SEQN"]))

# %%
nut_with_exam = rel_df.merge(df, on="SEQN")

# %%
nut_with_exam
# Out:
#        SEQN  DR1TKCAL  DR1TPROT  DR1TCARB  DR1TSUGR  DR1TFIBE  DR1TTFAT  \
# 0     73557    1574.0     43.63    239.59    176.47      10.8     52.81
# 1     73558    5062.0    338.13    423.78     44.99      16.7    124.29
# 2     73559    1743.0     64.61    224.39    102.90       9.9     65.97
# 3     73560    1490.0     77.75    162.92     80.58      10.6     58.27
# 4     73561    1421.0     55.24    178.20     87.78      12.3     55.36
# ...     ...       ...       ...       ...       ...       ...       ...
# 8526  83724    2432.0     77.09    384.72    164.56      22.2     69.26
# 8527  83727    4687.0    223.32    494.54    160.63      30.4    193.51
# 8528  83728    1253.0     47.55    149.20     50.73       9.3     52.39
# 8529  83729    2475.0     89.37    290.37    126.54      25.7    110.30
# 8530  83731    2877.0     96.06    461.53    221.21      36.3     78.63
#
#       DR1TSFAT  DR1TMFAT  DR1TPFAT  ...  DR1TCOPP  DR1TSODI  DR1TPOTA  \
# ...

# %%
nut_with_exam.dropna()
# Out:
#        SEQN  DR1TKCAL  DR1TPROT  DR1TCARB  DR1TSUGR  DR1TFIBE  DR1TTFAT  \
# 0     73557    1574.0     43.63    239.59    176.47      10.8     52.81
# 1     73558    5062.0    338.13    423.78     44.99      16.7    124.29
# 2     73559    1743.0     64.61    224.39    102.90       9.9     65.97
# 3     73560    1490.0     77.75    162.92     80.58      10.6     58.27
# 4     73561    1421.0     55.24    178.20     87.78      12.3     55.36
# ...     ...       ...       ...       ...       ...       ...       ...
# 8523  83721    1225.0     35.05    250.82    127.22      30.7     17.97
# 8526  83724    2432.0     77.09    384.72    164.56      22.2     69.26
# 8527  83727    4687.0    223.32    494.54    160.63      30.4    193.51
# 8529  83729    2475.0     89.37    290.37    126.54      25.7    110.30
# 8530  83731    2877.0     96.06    461.53    221.21      36.3     78.63
#
#       DR1TSFAT  DR1TMFAT  DR1TPFAT  ...  DR1TCOPP  DR1TSODI  DR1TPOTA  \
# ...

# %%
plot_corr(nut_with_exam.dropna().drop(columns=["SEQN"]))

# %%
q_df = pd.read_csv("../data/nhne/questionnaire.csv")
q_df.head()
# Out:
#     SEQN  ACD011A  ACD011B  ACD011C  ACD040  ACD110  ALQ101  ALQ110  ALQ120Q  \
# 0  73557      1.0      NaN      NaN     NaN     NaN     1.0     NaN      1.0
# 1  73558      1.0      NaN      NaN     NaN     NaN     1.0     NaN      7.0
# 2  73559      1.0      NaN      NaN     NaN     NaN     1.0     NaN      0.0
# 3  73560      1.0      NaN      NaN     NaN     NaN     NaN     NaN      NaN
# 4  73561      1.0      NaN      NaN     NaN     NaN     1.0     NaN      0.0
#
#    ALQ120U  ...  WHD080U  WHD080L  WHD110  WHD120  WHD130  WHD140  WHQ150  \
# 0      3.0  ...      NaN     40.0   270.0   200.0    69.0   270.0    62.0
# 1      1.0  ...      NaN      NaN   240.0   250.0    72.0   250.0    25.0
# 2      NaN  ...      NaN      NaN   180.0   190.0    70.0   228.0    35.0
# 3      NaN  ...      NaN      NaN     NaN     NaN     NaN     NaN     NaN
# 4      NaN  ...      NaN      NaN   150.0   135.0    67.0   170.0    60.0
#
#    WHQ030M  WHQ500  WHQ520
# 0      NaN     NaN     NaN
# ...

# %%
import pandas as pd
df = pd.read_csv("../data/nhne/diet.csv")
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
p_comps = pca.fit_transform(df)
p_df - pd.DataFrame(data=p_comps, columns=["comp1", "comp2"])
explained_var_ratio = pca.explained_variance_ratio_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-cb98bc21ef1d> in <module>
#       3 from sklearn.decomposition import PCA
#       4 pca=PCA(n_components=2)
# ----> 5 p_comps = pca.fit_transform(df)
#       6 p_df - pd.DataFrame(data=p_comps, columns=["comp1", "comp2"])
#       7 explained_var_ratio = pca.explained_variance_ratio_
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in fit_transform(self, X, y)
#     374         C-ordered array, use 'np.ascontiguousarray'.
#     375         """
# --> 376         U, S, V = self._fit(X)
#     377         U = U[:, :self.n_components_]
#     378
#
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/decomposition/_pca.py in _fit(self, X)
#     395                             'TruncatedSVD for a possible alternative.')
#     396
# ...
